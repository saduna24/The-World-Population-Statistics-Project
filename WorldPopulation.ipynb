# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./world_population.csv')

# %%
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df['CCA3']
# Out:
# 0      AFG
# 1      ALB
# 2      DZA
# 3      ASM
# 4      AND
#       ...
# 229    WLF
# 230    ESH
# 231    YEM
# 232    ZMB
# 233    ZWE
# Name: CCA3, Length: 234, dtype: object

# %%
#index

# %%
df = pd.read_csv('./world_population.csv', index_col='Rank')

# %%
df
# Out:
#      CCA3  Country/Territory           Capital Continent  2022 Population  \
# Rank
# 36    AFG        Afghanistan             Kabul      Asia         41128771
# 138   ALB            Albania            Tirana    Europe          2842321
# 34    DZA            Algeria           Algiers    Africa         44903225
# 213   ASM     American Samoa         Pago Pago   Oceania            44273
# 203   AND            Andorra  Andorra la Vella    Europe            79824
# ...   ...                ...               ...       ...              ...
# 226   WLF  Wallis and Futuna          Mata-Utu   Oceania            11572
# 172   ESH     Western Sahara          El Aaiún    Africa           575986
# 46    YEM              Yemen             Sanaa      Asia         33696614
# 63    ZMB             Zambia            Lusaka    Africa         20017675
# 74    ZWE           Zimbabwe            Harare    Africa         16320537
#
# ...

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.sort_index()
# Out:
#      CCA3 Country/Territory           Capital      Continent  2022 Population  \
# Rank
# 1     CHN             China           Beijing           Asia       1425887337
# 2     IND             India         New Delhi           Asia       1417173173
# 3     USA     United States  Washington, D.C.  North America        338289857
# 4     IDN         Indonesia           Jakarta           Asia        275501339
# 5     PAK          Pakistan         Islamabad           Asia        235824862
# ...   ...               ...               ...            ...              ...
# 230   MSR        Montserrat            Brades  North America             4390
# 231   FLK  Falkland Islands           Stanley  South America             3780
# 232   NIU              Niue             Alofi        Oceania             1934
# 233   TKL           Tokelau          Nukunonu        Oceania             1871
# 234   VAT      Vatican City      Vatican City         Europe              510
#
# ...

# %% [markdown]
# ## Filters

# %%
filt_Continent = df['Continent'] == 'Asia'

# %% [markdown]
# # 2022 population data above 100,000,000

# %%
filt_2022 = df['2022 Population'] > 100000000
filt_2022
# Out:
# Rank
# 36     False
# 138    False
# 34     False
# 213    False
# 203    False
#        ...
# 226    False
# 172    False
# 46     False
# 63     False
# 74     False
# Name: 2022 Population, Length: 234, dtype: bool

# %%
df.loc[filt_2022]
# Out:
#      CCA3 Country/Territory           Capital      Continent  2022 Population  \
# Rank
# 8     BGD        Bangladesh             Dhaka           Asia        171186372
# 7     BRA            Brazil          Brasilia  South America        215313498
# 1     CHN             China           Beijing           Asia       1425887337
# 14    EGY             Egypt             Cairo         Africa        110990103
# 12    ETH          Ethiopia       Addis Ababa         Africa        123379924
# 2     IND             India         New Delhi           Asia       1417173173
# 4     IDN         Indonesia           Jakarta           Asia        275501339
# 11    JPN             Japan             Tokyo           Asia        123951692
# 10    MEX            Mexico       Mexico City  North America        127504125
# 6     NGA           Nigeria             Abuja         Africa        218541212
# 5     PAK          Pakistan         Islamabad           Asia        235824862
# ...

# %%
df.loc[filt_2022, ['Continent', 'Country/Territory', 'World Population Percentage']]
# Out:
#           Continent Country/Territory  World Population Percentage
# Rank
# 8              Asia        Bangladesh                         2.15
# 7     South America            Brazil                         2.70
# 1              Asia             China                        17.88
# 14           Africa             Egypt                         1.39
# 12           Africa          Ethiopia                         1.55
# 2              Asia             India                        17.77
# 4              Asia         Indonesia                         3.45
# 11             Asia             Japan                         1.55
# 10    North America            Mexico                         1.60
# 6            Africa           Nigeria                         2.74
# 5              Asia          Pakistan                         2.96
# 13             Asia       Philippines                         1.45
# 9            Europe            Russia                         1.81
# ...

# %%
df.loc[filt_2022].head(5)
# Out:
#      CCA3 Country/Territory      Capital      Continent  2022 Population  \
# Rank
# 8     BGD        Bangladesh        Dhaka           Asia        171186372
# 7     BRA            Brazil     Brasilia  South America        215313498
# 1     CHN             China      Beijing           Asia       1425887337
# 14    EGY             Egypt        Cairo         Africa        110990103
# 12    ETH          Ethiopia  Addis Ababa         Africa        123379924
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 8           167420951        157830000        148391139        129193327
# 7           213196304        205188205        196353492        175873720
# 1          1424929781       1393715448       1348191368       1264099069
# 14          107465134         97723799         87252413         71371371
# 12          117190911        102471895         89237791         67031867
#
#       1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %% [markdown]
# ## Population data of Asia in the year 2022.

# %%
Asia = filt_2022[df['Continent'] == 'Asia']
Asia
# Out:
# Rank
# 36     False
# 140    False
# 91     False
# 154    False
# 8       True
# 165    False
# 175    False
# 73     False
# 1       True
# 131    False
# 104    False
# 2       True
# 4       True
# 17     False
# 35     False
# 98     False
# 11      True
# 83     False
# 66     False
# 129    False
# 110    False
# 103    False
# 119    False
# 167    False
# 45     False
# 174    False
# 134    False
# 26     False
# 49     False
# 56     False
# 127    False
# 5       True
# 122    False
# 13      True
# 143    False
# 41     False
# 113    False
# 29     False
# 61     False
# 60     False
# 57     False
# 95     False
# 20     False
# 155    False
# 18     False
# 111    False
# 97     False
# 43     False
# 16     False
# 46     False
# Name: 2022 Population, dtype: bool

# %% [markdown]
# ## Population data of Russia and Georgia in the year 2022.

# %%
countries = ['Russia','Georgia']
filt = df['Country/Territory'].isin(countries)
df.loc[filt, ['Continent', 'Country/Territory', 'World Population Percentage', '2022 Population']]
# Out:
#      Continent Country/Territory  World Population Percentage  2022 Population
# Rank
# 131       Asia           Georgia                         0.05          3744385
# 9       Europe            Russia                         1.81        144713314

# %%
df
# Out:
#      CCA3  Country/Territory           Capital Continent  2022 Population  \
# Rank
# 36    AFG        Afghanistan             Kabul      Asia         41128771
# 138   ALB            Albania            Tirana    Europe          2842321
# 34    DZA            Algeria           Algiers    Africa         44903225
# 213   ASM     American Samoa         Pago Pago   Oceania            44273
# 203   AND            Andorra  Andorra la Vella    Europe            79824
# ...   ...                ...               ...       ...              ...
# 226   WLF  Wallis and Futuna          Mata-Utu   Oceania            11572
# 172   ESH     Western Sahara          El Aaiún    Africa           575986
# 46    YEM              Yemen             Sanaa      Asia         33696614
# 63    ZMB             Zambia            Lusaka    Africa         20017675
# 74    ZWE           Zimbabwe            Harare    Africa         16320537
#
# ...

# %% [markdown]
# ## Sorting

# %%
df[['Country/Territory', '1980 Population']].head(50)
# Out:
#              Country/Territory  1980 Population
# Rank
# 36                 Afghanistan         12486631
# 138                    Albania          2941651
# 34                     Algeria         18739378
# 213             American Samoa            32886
# 203                    Andorra            35611
# 42                      Angola          8330047
# 224                   Anguilla             6560
# 201        Antigua and Barbuda            64888
# 33                   Argentina         28024803
# 140                    Armenia          3135123
# 198                      Aruba            62267
# 55                   Australia         14706322
# 99                     Austria          7547561
# 91                  Azerbaijan          6383060
# 176                    Bahamas           223752
# 154                    Bahrain           362595
# 8                   Bangladesh         83929765
# 186                   Barbados           253575
# ...

# %%
df['1980 Population'].nlargest(20)
# Out:
# Rank
# 1     982372466
# 2     696828385
# 3     223140018
# 4     148177096
# 9     138257420
# 7     122288383
# 11    117624196
# 8      83929765
# 5      80624057
# 19     77786703
# 6      72951439
# 10     67705186
# 25     56329482
# 21     56326328
# 23     53713830
# 16     52968270
# 38     49973920
# 13     48419546
# 20     45737753
# 18     44089069
# Name: 1980 Population, dtype: int64

# %%
df.nlargest(10, '1980 Population')['Country/Territory']
# Out:
# Rank
# 1             China
# 2             India
# 3     United States
# 4         Indonesia
# 9            Russia
# 7            Brazil
# 11            Japan
# 8        Bangladesh
# 5          Pakistan
# 19          Germany
# Name: Country/Territory, dtype: object

# %%
df.nlargest(10, '2022 Population')['Country/Territory']
# Out:
# Rank
# 1             China
# 2             India
# 3     United States
# 4         Indonesia
# 5          Pakistan
# 6           Nigeria
# 7            Brazil
# 8        Bangladesh
# 9            Russia
# 10           Mexico
# Name: Country/Territory, dtype: object

# %%
df.nlargest(10, 'Growth Rate')['Country/Territory']
# Out:
# Rank
# 135     Moldova
# 37       Poland
# 54        Niger
# 60        Syria
# 116    Slovakia
# 15     DR Congo
# 182     Mayotte
# 69         Chad
# 42       Angola
# 59         Mali
# Name: Country/Territory, dtype: object

# %%
df = df.sort_values(['Growth Rate', 'Country/Territory'], ascending=[True, True])
print(df)
# Out:
#      CCA3 Country/Territory     Capital Continent  2022 Population  \
# Rank
# 38    UKR           Ukraine        Kiev    Europe         39701739
# 119   LBN           Lebanon      Beirut      Asia          5489739
# 213   ASM    American Samoa   Pago Pago   Oceania            44273
# 108   BGR          Bulgaria       Sofia    Europe          6781953
# 141   LTU         Lithuania     Vilnius    Europe          2750055
# ...   ...               ...         ...       ...              ...
# 116   SVK          Slovakia  Bratislava    Europe          5643453
# 60    SYR             Syria    Damascus      Asia         22125249
# 54    NER             Niger      Niamey    Africa         26207977
# 37    POL            Poland      Warsaw    Europe         39857145
# 135   MDA           Moldova    Chisinau    Europe          3272996
#
#       2020 Population  2015 Population  2010 Population  2000 Population  \
# Rank
# 38           43909666         44982564         45683020         48879755
# ...

# %% [markdown]
# ## Static functions

# %%
df['2022 Population'].std()
# Out:
# 136766424.80476278

# %%
df['2000 Population'].std()
# Out:
# 111698206.71907005

# %%
country_grp = df.groupby(['Country/Territory']) 
country_grp

# %%
country_grp['1970 Population'].median()
# Out:
# Country/Territory
# Afghanistan          10752971.0
# Albania               2324731.0
# Algeria              13795915.0
# American Samoa          27075.0
# Andorra                 19860.0
#                         ...
# Wallis and Futuna        9377.0
# Western Sahara          76371.0
# Yemen                 6843607.0
# Zambia                4281671.0
# Zimbabwe              5202918.0
# Name: 1970 Population, Length: 234, dtype: float64

# %%
df['2000 Population'].median()
# Out:
# 4292907.0

# %%
df['2000 Population'].mean()
# Out:
# 26269468.816239316

# %%
country_grp['2022 Population'].agg(['median', 'mean']).loc['Georgia']
# Out:
# median    3744385.0
# mean      3744385.0
# Name: Georgia, dtype: float64

# %%
country_grp['1970 Population'].agg(['median', 'mean']).loc['Georgia']
# Out:
# median    4800426.0
# mean      4800426.0
# Name: Georgia, dtype: float64

# %%
df['2000 Population'].max()
# Out:
# 1264099069

# %%
df['2000 Population'].min()
# Out:
# 651

# %% [markdown]
# ## Numpy & Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Top 10 countries with the largest populations in 2022

# %%
top_10 = df.nlargest(10, '2022 Population')

# %%
plt.bar(top_10['Country/Territory'], top_10['2022 Population'], color='skyblue')


plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Top 10')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # World Population Timeline (1970-2022)

# %%
plt.subplots(figsize=(10,5))

growth = df.iloc[:,4:12].sum()[::-1]

sns.lineplot(x=growth.index, y=growth.values, marker="o")

plt.xticks(rotation=45)

plt.ylabel("Population")

plt.title("World Population Timeline (1970-2022)")

plt.show()
